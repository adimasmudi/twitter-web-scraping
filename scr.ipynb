# %%
pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: selenium in c:\program files\python311\lib\site-packages\selenium-4.7.0-py3.11.egg (4.7.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\program files\python311\lib\site-packages\urllib3-1.26.16-py3.11.egg (from selenium) (1.26.16)
# Requirement already satisfied: trio~=0.17 in c:\program files\python311\lib\site-packages\trio-0.22.0-py3.11.egg (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\program files\python311\lib\site-packages\trio_websocket-0.10.2-py3.11.egg (from selenium) (0.10.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\program files\python311\lib\site-packages\certifi-2023.5.7-py3.11.egg (from selenium) (2023.5.7)
# Requirement already satisfied: attrs>=19.2.0 in c:\program files\python311\lib\site-packages\attrs-23.1.0-py3.11.egg (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in c:\program files\python311\lib\site-packages\sortedcontainers-2.4.0-py3.11.egg (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\program files\python311\lib\site-packages\async_generator-1.10-py3.11.egg (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in c:\program files\python311\lib\site-packages\idna-3.4-py3.11.egg (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\program files\python311\lib\site-packages\outcome-1.2.0-py3.11.egg (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\program files\python311\lib\site-packages\sniffio-1.3.0-py3.11.egg (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\program files\python311\lib\site-packages\cffi-1.15.1-py3.11-win-amd64.egg (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: exceptiongroup in c:\program files\python311\lib\site-packages\exceptiongroup-1.1.1-py3.11.egg (from trio-websocket~=0.9->selenium) (1.1.1)
# Requirement already satisfied: wsproto>=0.14 in c:\program files\python311\lib\site-packages\wsproto-1.2.0-py3.11.egg (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\program files\python311\lib\site-packages\pysocks-1.7.1-py3.11.egg (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\program files\python311\lib\site-packages\pycparser-2.21-py3.11.egg (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\program files\python311\lib\site-packages\h11-0.14.0-py3.11.egg (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
import time
import csv
import itertools

driver = webdriver.Chrome()

driver.get("https://twitter.com/tvOneNews/status/1664422727346958336")

time.sleep(5)
    
tweets = []
result = False
old_height = driver.execute_script("return document.body.scrollHeight")

#set initial all_tweets to start loop
all_tweets = driver.find_elements(By.XPATH, '//div[@data-testid]//article[@data-testid="tweet"]')

while result == False:

    for item in all_tweets[1:]: # skip tweet already scrapped

        print('--- date ---')
        try:
            date = item.find_element(By.XPATH, './/time').text
        except:
            date = '[empty]'
        print(date)

        print('--- text ---')
        try:
            text = item.find_element(By.XPATH, './/div[@data-testid="tweetText"]').text
        except:
            text = '[empty]'
        print(text)

        print('--- replying_to ---')
        try:
            replying_to = item.find_element(By.XPATH, './/div[contains(text(), "Replying to")]//a').text
        except:
            replying_to = '[empty]'
        print(replying_to)
    
        #Append new tweets replies to tweet array
        tweets.append([date, replying_to, text])

    print('tweets disini :',tweets)
    
    #scroll down the page
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")

    time.sleep(2)
    
    try:
        try:
            button = driver.find_element_by_css_selector("div.css-901oao.r-1cvl2hr.r-37j5jr.r-a023e6.r-16dba41.r-rjixqe.r-bcqeeo.r-q4m81j.r-qvutc0")
        except:
            button = driver.find_element_by_css_selector("div.css-1dbjc4n.r-1ndi9ce") #there are two kinds of buttons
        
        ActionChains(driver).move_to_element(button).click(button).perform()
        time.sleep(2)
        driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
        time.sleep(2)
    except:
        pass

    new_height = driver.execute_script("return document.body.scrollHeight")

    if new_height == old_height:
        result = True
    old_height = new_height

    #update all_tweets to keep loop
    all_tweets = driver.find_elements(By.XPATH, '//div[@data-testid]//article[@data-testid="tweet"]')

    

# tweets = tweets.sort()
print('diakhir',tweets)
driver.close()

#save data to csv file
with open('lambang1.csv','w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['Date','Replying to','Text'])
    writer.writerows(tweets)
# Out:
# --- date ---
# Jun 2
# --- text ---
# Ya semoga mangkrak, aamiin.
# --- replying_to ---
# [empty]
# --- date ---
# Jun 2
# --- text ---
# Walah .. hanya gimmick yg memuakkan.
# Membuat logo pohon hayati tetapi realnya membuat pohon tidak hayat ..
# Kan lonthong .
# Asssuuuuudahlah
# --- replying_to ---
# [empty]
# --- date ---
# Jun 2
# --- text ---
# Hayat asal kata dari arab.. Nanti dikatakan kadrun?!
# --- replying_to ---
# [empty]
# --- date ---
# Jun 2
# --- text ---
# [empty]
# --- replying_to ---
# [empty]
# --- date ---
# Jun 2
# --- text ---
#
udah. Biarkan aja. IKN gak bakal lanjut kok. Mau pake logo apapun gak ngefek.. kecuali ada yg main kayu'], ['Jun 2', '[empty]', 'Yg biki ...
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
# Pohon hayat ada ya ? Bisa jadi ada ainul hayat dinusantara slurr
# --- replying_to ---
# [empty]
# --- date ---
# Jun 2
# --- text ---
# Sibuk terus dgn tagline.
# --- replying_to ---
# [empty]
# --- date ---
# Jun 2
# --- text ---
# Padahal ada pohon rambutan, pohon kelapa dll, knapa milih pohon hayat.
# HHHHH
# --- replying_to ---
# [empty]
# --- date ---
# Jun 2
# --- text ---
# Kyak gmana sih phonnya?
# --- replying_to ---
# [empty]
# --- date ---
# Jun 2
# --- text ---
# Knapa gak pohon sawit? Kan dsana banyak
# --- replying_to ---
# [empty]
# --- date ---
# Jun 2
# --- text ---
# Rajin bangat bikin narasi provokasi
# --- replying_to ---
# [empty]
# --- date ---
# Jun 2
# --- text ---
# Napa alkitab
# --- replying_to ---
# [empty]
# --- date ---
# Jun 2
# --- text ---
# Pohon MAYAT??
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# tweets disini : [['Jun 2', '[empty]', 'Ya semoga mangkrak, aamiin.'], ['Jun 2', '[empty]', 'Walah .. hanya gimmick yg memuakkan.\nMembuat logo pohon hayati tetapi realnya membuat pohon tidak hayat .. \nKan lonthong .\nAsssuuuuudahlah'], ['Jun 2', '[empty]', 'Hayat asal kata dari arab.. Nanti dikatakan kadrun?!'], ['Jun 2', '[empty]', '[empty]'], ['Jun 2', '[empty]', 'Logo itu pakai Garuda Pancasila...selesai..'], ['Jun 2', '[empty]', 'Logonya pohon tidak berdaun karena daunnya sudah dibabat oleh yang punya proyek '], ['Jun 2', '[empty]', 'Lah terus kalau ada di Alkitab emg ngapa? Bego nih yg buat artikel.'], ['Jun 2', '[empty]', 'Yang mendesign namanya Aulia Akbar….dari namanya 99% terlihat agamanya apa, kecuali orang tuanya pengen terlalu unik.'], ['Jun 2', '[empty]', 'Mirip dajjal'], ['Jun 2', '[empty]', 'Waduh ...... Aku gak ikut milih euy... sayank sekali'], ['Jun 2', '[empty]', 'Ya semoga mangkrak, aamiin.'], ['Jun 2', '[empty]', 'Walah .. hanya gimmick yg memuakkan.\nMembuat logo pohon hayati tetapi realnya membuat pohon tidak hayat .. \nKan lonthong .\nAsssuuuuudahlah'], ['Jun 2', '[empty]', 'Hayat asal kata dari arab.. Nanti dikatakan kadrun?!'], ['Jun 2', '[empty]', '[empty]'], ['Jun 2', '[empty]', 'Logo itu pakai Garuda Pancasila...selesai..'], ['Jun 2', '[empty]', 'Logonya pohon tidak berdaun karena daunnya sudah dibabat oleh yang punya proyek '], ['Jun 2', '[empty]', 'Lah terus kalau ada di Alkitab emg ngapa? Bego nih yg buat artikel.'], ['Jun 2', '[empty]', 'Yang mendesign namanya Aulia Akbar….dari namanya 99% terlihat agamanya apa, kecuali orang tuanya pengen terlalu unik.'], ['Jun 2', '[empty]', 'Mirip dajjal'], ['Jun 2', '[empty]', 'Waduh ...... Aku gak ikut milih euy... sayank sekali'], ['Jun 2', '[empty]', 'Bukan hanya pohon yg ada disitu. Adam dan hawa pun ada di situ. Tolol kok dipelihara'], ['Jun 2', '[empty]', 'Sudahlah segala logo dimasalahin'], ['Jun 2', '[empty]', 'Hahaha modyar'], ['Jun 2', '[empty]', 'Biaya IkN ratusan triliun hasilnya cuma logo doang..'], ['Jun 2', '[empty]', 'IKN hanya imajinasi mukidi, ngibul dan bahlul.'], ['Jun 2', '[empty]', '.. pindah ibukota serasa pindah kontrakan '], ['Jun 2', '[empty]', '.. pindah ibukota serasa pindah kontrakan '], ['Jun 2', '[empty]', '@Uing0095\n katanya yg Pilih itu Rakyat. rakyat mana ya??? lihat aja baru, boro² milih... Maneh Ngacapruk'], ['Jun 2', '[empty]', 'IKN = IBU KOTA NGUTANG'], ['Jun 2', '[empty]', 'IKN Residence, senin harga naik, sabtu diskon lagi..'], ['Jun 2', '[empty]', 'Kenapa gak pake lambang burung garuda aja biar kelihatan pancasila nya'], ['Jun 2', '[empty]', 'Admin nya emank sengaja jadi provokator terus kenapa kalau di Alkitab??? Hedewww'], ['Jun 2', '[empty]', 'IKN= IBU KOTA NGEDABRUS iya ga pak de \n@jokowi'], ['Jun 2', '[empty]', 'bisa saja desain pohon hayat menggambarkan bahwa rencana IKN hingga akhir hayat gak bakal bisa terwujud. '], ['Jun 2', '[empty]', 'Logo pohon, tapi pohon d kalimantan dibabat'], ['Jun 2', '[empty]', 'Pohon Kehidupan Suku Dayak Ngaju, Kalteng'], ['Jun 2', '[empty]', 'IKN bakalan jadi akan mangkrak..'], ['Jun 2', '[empty]', 'Kenapa gak pake lambang burung garuda aja biar kelihatan pancasila nya'], ['Jun 2', '[empty]', 'Admin nya emank sengaja jadi provokator terus kenapa kalau di Alkitab??? Hedewww'], ['Jun 2', '[empty]', 'IKN= IBU KOTA NGEDABRUS iya ga pak de \n@jokowi'], ['Jun 2', '[empty]', 'bisa saja desain pohon hayat menggambarkan bahwa rencana IKN hingga akhir hayat gak bakal bisa terwujud. '], ['Jun 2', '[empty]', 'Logo pohon, tapi pohon d kalimantan dibabat'], ['Jun 2', '[empty]', 'Pohon Kehidupan Suku Dayak Ngaju, Kalteng'], ['Jun 2', '[empty]', 'IKN bakalan jadi akan mangkrak..'], ['Jun 2', '[empty]', 'Logonya pohon, tp pohonnya ditebang.'], ['Jun 2', '[empty]', 'Logonya lebih terlihat seperti logo kaum pagan para penyembah matahari!'], ['Jun 2', '[empty]', 'Udah. Biarkan aja. IKN gak bakal lanjut kok. Mau pake logo apapun gak ngefek.. kecuali ada yg main kayu'], ['Jun 2', '[empty]', 'Yg biki ...
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
# [empty]
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
# Jun 2
# --- text ---
# Masih aja di hubungkan dengan agama hehehe... kreatif ya netizen kita. Lama lama bisa dijadikan bom waktu sama org yg ga bertanggung jawab.
# --- replying_to ---
# [empty]
# --- date ---
# Jun 2
# --- text ---
# Kadrun kejang2
# --- replying_to ---
# [empty]
# --- date ---
# Jun 2
# --- text ---
# Kayak bakal beneran jadi aje tuh project Bancakan
# --- replying_to ---
# [empty]
# --- date ---
# Jun 2
# --- text ---
# Apa pesanan atau perancang lalukan keyakinannya..?
# --- replying_to ---
# [empty]
# --- date ---
# Jun 2
# --- text ---
# Semoga Indonesia jadi negara Kristen
# --- replying_to ---
# [empty]
# --- date ---
# Jun 2
# --- text ---
# logonya pohon tapi ngebabat pohon
# --- replying_to ---
# [empty]
# --- date ---
# Jun 2
# --- text ---
# Lambang pohon tapi pohon di babat abis
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
# [empty]
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# tweets disini : [['Jun 2', '[empty]', 'Ya semoga mangkrak, aamiin.'], ['Jun 2', '[empty]', 'Walah .. hanya gimmick yg memuakkan.\nMembuat logo pohon hayati tetapi realnya membuat pohon tidak hayat .. \nKan lonthong .\nAsssuuuuudahlah'], ['Jun 2', '[empty]', 'Hayat asal kata dari arab.. Nanti dikatakan kadrun?!'], ['Jun 2', '[empty]', '[empty]'], ['Jun 2', '[empty]', 'Logo itu pakai Garuda Pancasila...selesai..'], ['Jun 2', '[empty]', 'Logonya pohon tidak berdaun karena daunnya sudah dibabat oleh yang punya proyek '], ['Jun 2', '[empty]', 'Lah terus kalau ada di Alkitab emg ngapa? Bego nih yg buat artikel.'], ['Jun 2', '[empty]', 'Yang mendesign namanya Aulia Akbar….dari namanya 99% terlihat agamanya apa, kecuali orang tuanya pengen terlalu unik.'], ['Jun 2', '[empty]', 'Mirip dajjal'], ['Jun 2', '[empty]', 'Waduh ...... Aku gak ikut milih euy... sayank sekali'], ['Jun 2', '[empty]', 'Ya semoga mangkrak, aamiin.'], ['Jun 2', '[empty]', 'Walah .. hanya gimmick yg memuakkan.\nMembuat logo pohon hayati tetapi realnya membuat pohon tidak hayat .. \nKan lonthong .\nAsssuuuuudahlah'], ['Jun 2', '[empty]', 'Hayat asal kata dari arab.. Nanti dikatakan kadrun?!'], ['Jun 2', '[empty]', '[empty]'], ['Jun 2', '[empty]', 'Logo itu pakai Garuda Pancasila...selesai..'], ['Jun 2', '[empty]', 'Logonya pohon tidak berdaun karena daunnya sudah dibabat oleh yang punya proyek '], ['Jun 2', '[empty]', 'Lah terus kalau ada di Alkitab emg ngapa? Bego nih yg buat artikel.'], ['Jun 2', '[empty]', 'Yang mendesign namanya Aulia Akbar….dari namanya 99% terlihat agamanya apa, kecuali orang tuanya pengen terlalu unik.'], ['Jun 2', '[empty]', 'Mirip dajjal'], ['Jun 2', '[empty]', 'Waduh ...... Aku gak ikut milih euy... sayank sekali'], ['Jun 2', '[empty]', 'Bukan hanya pohon yg ada disitu. Adam dan hawa pun ada di situ. Tolol kok dipelihara'], ['Jun 2', '[empty]', 'Sudahlah segala logo dimasalahin'], ['Jun 2', '[empty]', 'Hahaha modyar'], ['Jun 2', '[empty]', 'Biaya IkN ratusan triliun hasilnya cuma logo doang..'], ['Jun 2', '[empty]', 'IKN hanya imajinasi mukidi, ngibul dan bahlul.'], ['Jun 2', '[empty]', '.. pindah ibukota serasa pindah kontrakan '], ['Jun 2', '[empty]', '.. pindah ibukota serasa pindah kontrakan '], ['Jun 2', '[empty]', '@Uing0095\n katanya yg Pilih itu Rakyat. rakyat mana ya??? lihat aja baru, boro² milih... Maneh Ngacapruk'], ['Jun 2', '[empty]', 'IKN = IBU KOTA NGUTANG'], ['Jun 2', '[empty]', 'IKN Residence, senin harga naik, sabtu diskon lagi..'], ['Jun 2', '[empty]', 'Kenapa gak pake lambang burung garuda aja biar kelihatan pancasila nya'], ['Jun 2', '[empty]', 'Admin nya emank sengaja jadi provokator terus kenapa kalau di Alkitab??? Hedewww'], ['Jun 2', '[empty]', 'IKN= IBU KOTA NGEDABRUS iya ga pak de \n@jokowi'], ['Jun 2', '[empty]', 'bisa saja desain pohon hayat menggambarkan bahwa rencana IKN hingga akhir hayat gak bakal bisa terwujud. '], ['Jun 2', '[empty]', 'Logo pohon, tapi pohon d kalimantan dibabat'], ['Jun 2', '[empty]', 'Pohon Kehidupan Suku Dayak Ngaju, Kalteng'], ['Jun 2', '[empty]', 'IKN bakalan jadi akan mangkrak..'], ['Jun 2', '[empty]', 'Kenapa gak pake lambang burung garuda aja biar kelihatan pancasila nya'], ['Jun 2', '[empty]', 'Admin nya emank sengaja jadi provokator terus kenapa kalau di Alkitab??? Hedewww'], ['Jun 2', '[empty]', 'IKN= IBU KOTA NGEDABRUS iya ga pak de \n@jokowi'], ['Jun 2', '[empty]', 'bisa saja desain pohon hayat menggambarkan bahwa rencana IKN hingga akhir hayat gak bakal bisa terwujud. '], ['Jun 2', '[empty]', 'Logo pohon, tapi pohon d kalimantan dibabat'], ['Jun 2', '[empty]', 'Pohon Kehidupan Suku Dayak Ngaju, Kalteng'], ['Jun 2', '[empty]', 'IKN bakalan jadi akan mangkrak..'], ['Jun 2', '[empty]', 'Logonya pohon, tp pohonnya ditebang.'], ['Jun 2', '[empty]', 'Logonya lebih terlihat seperti logo kaum pagan para penyembah matahari!'], ['Jun 2', '[empty]', 'Udah. Biarkan aja. IKN gak bakal lanjut kok. Mau pake logo apapun gak ngefek.. kecuali ada yg main kayu'], ['Jun 2', '[empty]', 'Yg biki ...
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
# Penebangan pohon diganti logo.
# --- replying_to ---
# [empty]
# --- date ---
# Jun 2
# --- text ---
# Simbol dajal
# --- replying_to ---
# [empty]
# --- date ---
# Jun 2
# --- text ---
# I suggest coconut tree for ikn symbol
# --- replying_to ---
# [empty]
# --- date ---
# Jun 3
# --- text ---
# Ga jelas lu semua ... Seneng amat nyocok nyocokin
# --- replying_to ---
# [empty]
# --- date ---
# Jun 3
# --- text ---
# Logonya tak suka
# --- replying_to ---
# [empty]
# --- date ---
# Jun 3
# --- text ---
# Jangankan IKN. Naypiydaw di myanmar, Xiongan di China aja kosong. Biarin aja investor duitnya mandek disitu
# --- replying_to ---
# [empty]
# --- date ---
# Jun 3
# --- text ---
# Lambang Pohon Hayat, tp pembangunannya nebang berapa ratusan ribu hektar POHON nanti? Wkwkwkwk lawak
# --- replying_to ---
# [empty]
# --- date ---
# Jun 3
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# tweets disini : [['Jun 2', '[empty]', 'Ya semoga mangkrak, aamiin.'], ['Jun 2', '[empty]', 'Walah .. hanya gimmick yg memuakkan.\nMembuat logo pohon hayati tetapi realnya membuat pohon tidak hayat .. \nKan lonthong .\nAsssuuuuudahlah'], ['Jun 2', '[empty]', 'Hayat asal kata dari arab.. Nanti dikatakan kadrun?!'], ['Jun 2', '[empty]', '[empty]'], ['Jun 2', '[empty]', 'Logo itu pakai Garuda Pancasila...selesai..'], ['Jun 2', '[empty]', 'Logonya pohon tidak berdaun karena daunnya sudah dibabat oleh yang punya proyek '], ['Jun 2', '[empty]', 'Lah terus kalau ada di Alkitab emg ngapa? Bego nih yg buat artikel.'], ['Jun 2', '[empty]', 'Yang mendesign namanya Aulia Akbar….dari namanya 99% terlihat agamanya apa, kecuali orang tuanya pengen terlalu unik.'], ['Jun 2', '[empty]', 'Mirip dajjal'], ['Jun 2', '[empty]', 'Waduh ...... Aku gak ikut milih euy... sayank sekali'], ['Jun 2', '[empty]', 'Ya semoga mangkrak, aamiin.'], ['Jun 2', '[empty]', 'Walah .. hanya gimmick yg memuakkan.\nMembuat logo pohon hayati tetapi realnya membuat pohon tidak hayat .. \nKan lonthong .\nAsssuuuuudahlah'], ['Jun 2', '[empty]', 'Hayat asal kata dari arab.. Nanti dikatakan kadrun?!'], ['Jun 2', '[empty]', '[empty]'], ['Jun 2', '[empty]', 'Logo itu pakai Garuda Pancasila...selesai..'], ['Jun 2', '[empty]', 'Logonya pohon tidak berdaun karena daunnya sudah dibabat oleh yang punya proyek '], ['Jun 2', '[empty]', 'Lah terus kalau ada di Alkitab emg ngapa? Bego nih yg buat artikel.'], ['Jun 2', '[empty]', 'Yang mendesign namanya Aulia Akbar….dari namanya 99% terlihat agamanya apa, kecuali orang tuanya pengen terlalu unik.'], ['Jun 2', '[empty]', 'Mirip dajjal'], ['Jun 2', '[empty]', 'Waduh ...... Aku gak ikut milih euy... sayank sekali'], ['Jun 2', '[empty]', 'Bukan hanya pohon yg ada disitu. Adam dan hawa pun ada di situ. Tolol kok dipelihara'], ['Jun 2', '[empty]', 'Sudahlah segala logo dimasalahin'], ['Jun 2', '[empty]', 'Hahaha modyar'], ['Jun 2', '[empty]', 'Biaya IkN ratusan triliun hasilnya cuma logo doang..'], ['Jun 2', '[empty]', 'IKN hanya imajinasi mukidi, ngibul dan bahlul.'], ['Jun 2', '[empty]', '.. pindah ibukota serasa pindah kontrakan '], ['Jun 2', '[empty]', '.. pindah ibukota serasa pindah kontrakan '], ['Jun 2', '[empty]', '@Uing0095\n katanya yg Pilih itu Rakyat. rakyat mana ya??? lihat aja baru, boro² milih... Maneh Ngacapruk'], ['Jun 2', '[empty]', 'IKN = IBU KOTA NGUTANG'], ['Jun 2', '[empty]', 'IKN Residence, senin harga naik, sabtu diskon lagi..'], ['Jun 2', '[empty]', 'Kenapa gak pake lambang burung garuda aja biar kelihatan pancasila nya'], ['Jun 2', '[empty]', 'Admin nya emank sengaja jadi provokator terus kenapa kalau di Alkitab??? Hedewww'], ['Jun 2', '[empty]', 'IKN= IBU KOTA NGEDABRUS iya ga pak de \n@jokowi'], ['Jun 2', '[empty]', 'bisa saja desain pohon hayat menggambarkan bahwa rencana IKN hingga akhir hayat gak bakal bisa terwujud. '], ['Jun 2', '[empty]', 'Logo pohon, tapi pohon d kalimantan dibabat'], ['Jun 2', '[empty]', 'Pohon Kehidupan Suku Dayak Ngaju, Kalteng'], ['Jun 2', '[empty]', 'IKN bakalan jadi akan mangkrak..'], ['Jun 2', '[empty]', 'Kenapa gak pake lambang burung garuda aja biar kelihatan pancasila nya'], ['Jun 2', '[empty]', 'Admin nya emank sengaja jadi provokator terus kenapa kalau di Alkitab??? Hedewww'], ['Jun 2', '[empty]', 'IKN= IBU KOTA NGEDABRUS iya ga pak de \n@jokowi'], ['Jun 2', '[empty]', 'bisa saja desain pohon hayat menggambarkan bahwa rencana IKN hingga akhir hayat gak bakal bisa terwujud. '], ['Jun 2', '[empty]', 'Logo pohon, tapi pohon d kalimantan dibabat'], ['Jun 2', '[empty]', 'Pohon Kehidupan Suku Dayak Ngaju, Kalteng'], ['Jun 2', '[empty]', 'IKN bakalan jadi akan mangkrak..'], ['Jun 2', '[empty]', 'Logonya pohon, tp pohonnya ditebang.'], ['Jun 2', '[empty]', 'Logonya lebih terlihat seperti logo kaum pagan para penyembah matahari!'], ['Jun 2', '[empty]', 'Udah. Biarkan aja. IKN gak bakal lanjut kok. Mau pake logo apapun gak ngefek.. kecuali ada yg main kayu'], ['Jun 2', '[empty]', 'Yg biki ...
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
# Jun 3
# --- text ---
# Ada yg pernah ke kota pemerintahan malaysia, kota Putra Jaya ?  saya sih lebih betah di KL. Akankah IKN seperti putra jaya ?  Atau naypiydaw myanmar?
# --- replying_to ---
# [empty]
# --- date ---
# Jun 3
# --- text ---
# Padahal di #Canva  yg berbayar banyak template logo
# --- replying_to ---
# [empty]
# --- date ---
# Jun 3
# --- text ---
# Klo dilihat lihat gambar itu artinya
# "Pohonnya di tebang jadilah panas kena terik matahari"
# --- replying_to ---
# [empty]
# --- date ---
# Jun 3
# --- text ---
# Media kok mainnya berita menjurus provokasi,
# --- replying_to ---
# [empty]
# --- date ---
# Jun 3
# --- text ---
# Terinspirasi dari simbol Yahudi
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
# [empty]
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# --- date ---
#
# --- text ---
#
# --- replying_to ---
# [empty]
# tweets disini : [['Jun 2', '[empty]', 'Ya semoga mangkrak, aamiin.'], ['Jun 2', '[empty]', 'Walah .. hanya gimmick yg memuakkan.\nMembuat logo pohon hayati tetapi realnya membuat pohon tidak hayat .. \nKan lonthong .\nAsssuuuuudahlah'], ['Jun 2', '[empty]', 'Hayat asal kata dari arab.. Nanti dikatakan kadrun?!'], ['Jun 2', '[empty]', '[empty]'], ['Jun 2', '[empty]', 'Logo itu pakai Garuda Pancasila...selesai..'], ['Jun 2', '[empty]', 'Logonya pohon tidak berdaun karena daunnya sudah dibabat oleh yang punya proyek '], ['Jun 2', '[empty]', 'Lah terus kalau ada di Alkitab emg ngapa? Bego nih yg buat artikel.'], ['Jun 2', '[empty]', 'Yang mendesign namanya Aulia Akbar….dari namanya 99% terlihat agamanya apa, kecuali orang tuanya pengen terlalu unik.'], ['Jun 2', '[empty]', 'Mirip dajjal'], ['Jun 2', '[empty]', 'Waduh ...... Aku gak ikut milih euy... sayank sekali'], ['Jun 2', '[empty]', 'Ya semoga mangkrak, aamiin.'], ['Jun 2', '[empty]', 'Walah .. hanya gimmick yg memuakkan.\nMembuat logo pohon hayati tetapi realnya membuat pohon tidak hayat .. \nKan lonthong .\nAsssuuuuudahlah'], ['Jun 2', '[empty]', 'Hayat asal kata dari arab.. Nanti dikatakan kadrun?!'], ['Jun 2', '[empty]', '[empty]'], ['Jun 2', '[empty]', 'Logo itu pakai Garuda Pancasila...selesai..'], ['Jun 2', '[empty]', 'Logonya pohon tidak berdaun karena daunnya sudah dibabat oleh yang punya proyek '], ['Jun 2', '[empty]', 'Lah terus kalau ada di Alkitab emg ngapa? Bego nih yg buat artikel.'], ['Jun 2', '[empty]', 'Yang mendesign namanya Aulia Akbar….dari namanya 99% terlihat agamanya apa, kecuali orang tuanya pengen terlalu unik.'], ['Jun 2', '[empty]', 'Mirip dajjal'], ['Jun 2', '[empty]', 'Waduh ...... Aku gak ikut milih euy... sayank sekali'], ['Jun 2', '[empty]', 'Bukan hanya pohon yg ada disitu. Adam dan hawa pun ada di situ. Tolol kok dipelihara'], ['Jun 2', '[empty]', 'Sudahlah segala logo dimasalahin'], ['Jun 2', '[empty]', 'Hahaha modyar'], ['Jun 2', '[empty]', 'Biaya IkN ratusan triliun hasilnya cuma logo doang..'], ['Jun 2', '[empty]', 'IKN hanya imajinasi mukidi, ngibul dan bahlul.'], ['Jun 2', '[empty]', '.. pindah ibukota serasa pindah kontrakan '], ['Jun 2', '[empty]', '.. pindah ibukota serasa pindah kontrakan '], ['Jun 2', '[empty]', '@Uing0095\n katanya yg Pilih itu Rakyat. rakyat mana ya??? lihat aja baru, boro² milih... Maneh Ngacapruk'], ['Jun 2', '[empty]', 'IKN = IBU KOTA NGUTANG'], ['Jun 2', '[empty]', 'IKN Residence, senin harga naik, sabtu diskon lagi..'], ['Jun 2', '[empty]', 'Kenapa gak pake lambang burung garuda aja biar kelihatan pancasila nya'], ['Jun 2', '[empty]', 'Admin nya emank sengaja jadi provokator terus kenapa kalau di Alkitab??? Hedewww'], ['Jun 2', '[empty]', 'IKN= IBU KOTA NGEDABRUS iya ga pak de \n@jokowi'], ['Jun 2', '[empty]', 'bisa saja desain pohon hayat menggambarkan bahwa rencana IKN hingga akhir hayat gak bakal bisa terwujud. '], ['Jun 2', '[empty]', 'Logo pohon, tapi pohon d kalimantan dibabat'], ['Jun 2', '[empty]', 'Pohon Kehidupan Suku Dayak Ngaju, Kalteng'], ['Jun 2', '[empty]', 'IKN bakalan jadi akan mangkrak..'], ['Jun 2', '[empty]', 'Kenapa gak pake lambang burung garuda aja biar kelihatan pancasila nya'], ['Jun 2', '[empty]', 'Admin nya emank sengaja jadi provokator terus kenapa kalau di Alkitab??? Hedewww'], ['Jun 2', '[empty]', 'IKN= IBU KOTA NGEDABRUS iya ga pak de \n@jokowi'], ['Jun 2', '[empty]', 'bisa saja desain pohon hayat menggambarkan bahwa rencana IKN hingga akhir hayat gak bakal bisa terwujud. '], ['Jun 2', '[empty]', 'Logo pohon, tapi pohon d kalimantan dibabat'], ['Jun 2', '[empty]', 'Pohon Kehidupan Suku Dayak Ngaju, Kalteng'], ['Jun 2', '[empty]', 'IKN bakalan jadi akan mangkrak..'], ['Jun 2', '[empty]', 'Logonya pohon, tp pohonnya ditebang.'], ['Jun 2', '[empty]', 'Logonya lebih terlihat seperti logo kaum pagan para penyembah matahari!'], ['Jun 2', '[empty]', 'Udah. Biarkan aja. IKN gak bakal lanjut kok. Mau pake logo apapun gak ngefek.. kecuali ada yg main kayu'], ['Jun 2', '[empty]', 'Yg biki ...
# --- date ---
# Jun 3
# --- text ---
# Terinspirasi dari simbol Yahudi
# --- replying_to ---
# [empty]
# --- date ---
# Jun 3
# --- text ---
# Harusnya logonya Pohong Keju,nikmaaat....
# --- replying_to ---
# [empty]
# --- date ---
# Jun 3
# --- text ---
# [empty]
# --- replying_to ---
# [empty]
# --- date ---
# 19h
# --- text ---
# Garuda Pancasila Lambang NKRI harga mati. Di setiap Kab/Kota ada lambangnya. Begitu juga setiap Propinsi/Dl/DOK/DKI, ada lambangnya. Bagaimana IKN ,,? Perlu ada atau tidak,,?.
# --- replying_to ---
# [empty]
# --- date ---
# 18h
# --- text ---
# Mata satu versi baru
# --- replying_to ---
# [empty]
# --- date ---
# 16h
# --- text ---
# Emang IKN mau jadi gituh...??
# --- replying_to ---
# [empty]
# --- date ---
# 13h
# --- text ---
# Memangnya kalau ada dalam Alkitab,tidak sah gitu....?
# --- replying_to ---
# [empty]
# --- date ---
# 10h
# --- text ---
# Viralkan massive...
# --- replying_to ---
# [empty]
# --- date ---
# 4h
# --- text ---
# [empty]
# --- replying_to ---
# [empty]
# --- date ---
# 15h
# --- text ---
# Nyooooookkkk. . .
#
# Yenny Wahid Ajak Gusdurian untuk Dukung Anies Baswedan
# https://hajinews.id/2022/08/22/yenny-wahid-ajak-gusdurian-untuk-dukung-anies-baswedan/…
#
# #JokowiLuhutSumberPetaka
# #JokowiLuhutSumberPetaka
# --- replying_to ---
# [empty]
# tweets disini : [['Jun 2', '[empty]', 'Ya semoga mangkrak, aamiin.'], ['Jun 2', '[empty]', 'Walah .. hanya gimmick yg memuakkan.\nMembuat logo pohon hayati tetapi realnya membuat pohon tidak hayat .. \nKan lonthong .\nAsssuuuuudahlah'], ['Jun 2', '[empty]', 'Hayat asal kata dari arab.. Nanti dikatakan kadrun?!'], ['Jun 2', '[empty]', '[empty]'], ['Jun 2', '[empty]', 'Logo itu pakai Garuda Pancasila...selesai..'], ['Jun 2', '[empty]', 'Logonya pohon tidak berdaun karena daunnya sudah dibabat oleh yang punya proyek '], ['Jun 2', '[empty]', 'Lah terus kalau ada di Alkitab emg ngapa? Bego nih yg buat artikel.'], ['Jun 2', '[empty]', 'Yang mendesign namanya Aulia Akbar….dari namanya 99% terlihat agamanya apa, kecuali orang tuanya pengen terlalu unik.'], ['Jun 2', '[empty]', 'Mirip dajjal'], ['Jun 2', '[empty]', 'Waduh ...... Aku gak ikut milih euy... sayank sekali'], ['Jun 2', '[empty]', 'Ya semoga mangkrak, aamiin.'], ['Jun 2', '[empty]', 'Walah .. hanya gimmick yg memuakkan.\nMembuat logo pohon hayati tetapi realnya membuat pohon tidak hayat .. \nKan lonthong .\nAsssuuuuudahlah'], ['Jun 2', '[empty]', 'Hayat asal kata dari arab.. Nanti dikatakan kadrun?!'], ['Jun 2', '[empty]', '[empty]'], ['Jun 2', '[empty]', 'Logo itu pakai Garuda Pancasila...selesai..'], ['Jun 2', '[empty]', 'Logonya pohon tidak berdaun karena daunnya sudah dibabat oleh yang punya proyek '], ['Jun 2', '[empty]', 'Lah terus kalau ada di Alkitab emg ngapa? Bego nih yg buat artikel.'], ['Jun 2', '[empty]', 'Yang mendesign namanya Aulia Akbar….dari namanya 99% terlihat agamanya apa, kecuali orang tuanya pengen terlalu unik.'], ['Jun 2', '[empty]', 'Mirip dajjal'], ['Jun 2', '[empty]', 'Waduh ...... Aku gak ikut milih euy... sayank sekali'], ['Jun 2', '[empty]', 'Bukan hanya pohon yg ada disitu. Adam dan hawa pun ada di situ. Tolol kok dipelihara'], ['Jun 2', '[empty]', 'Sudahlah segala logo dimasalahin'], ['Jun 2', '[empty]', 'Hahaha modyar'], ['Jun 2', '[empty]', 'Biaya IkN ratusan triliun hasilnya cuma logo doang..'], ['Jun 2', '[empty]', 'IKN hanya imajinasi mukidi, ngibul dan bahlul.'], ['Jun 2', '[empty]', '.. pindah ibukota serasa pindah kontrakan '], ['Jun 2', '[empty]', '.. pindah ibukota serasa pindah kontrakan '], ['Jun 2', '[empty]', '@Uing0095\n katanya yg Pilih itu Rakyat. rakyat mana ya??? lihat aja baru, boro² milih... Maneh Ngacapruk'], ['Jun 2', '[empty]', 'IKN = IBU KOTA NGUTANG'], ['Jun 2', '[empty]', 'IKN Residence, senin harga naik, sabtu diskon lagi..'], ['Jun 2', '[empty]', 'Kenapa gak pake lambang burung garuda aja biar kelihatan pancasila nya'], ['Jun 2', '[empty]', 'Admin nya emank sengaja jadi provokator terus kenapa kalau di Alkitab??? Hedewww'], ['Jun 2', '[empty]', 'IKN= IBU KOTA NGEDABRUS iya ga pak de \n@jokowi'], ['Jun 2', '[empty]', 'bisa saja desain pohon hayat menggambarkan bahwa rencana IKN hingga akhir hayat gak bakal bisa terwujud. '], ['Jun 2', '[empty]', 'Logo pohon, tapi pohon d kalimantan dibabat'], ['Jun 2', '[empty]', 'Pohon Kehidupan Suku Dayak Ngaju, Kalteng'], ['Jun 2', '[empty]', 'IKN bakalan jadi akan mangkrak..'], ['Jun 2', '[empty]', 'Kenapa gak pake lambang burung garuda aja biar kelihatan pancasila nya'], ['Jun 2', '[empty]', 'Admin nya emank sengaja jadi provokator terus kenapa kalau di Alkitab??? Hedewww'], ['Jun 2', '[empty]', 'IKN= IBU KOTA NGEDABRUS iya ga pak de \n@jokowi'], ['Jun 2', '[empty]', 'bisa saja desain pohon hayat menggambarkan bahwa rencana IKN hingga akhir hayat gak bakal bisa terwujud. '], ['Jun 2', '[empty]', 'Logo pohon, tapi pohon d kalimantan dibabat'], ['Jun 2', '[empty]', 'Pohon Kehidupan Suku Dayak Ngaju, Kalteng'], ['Jun 2', '[empty]', 'IKN bakalan jadi akan mangkrak..'], ['Jun 2', '[empty]', 'Logonya pohon, tp pohonnya ditebang.'], ['Jun 2', '[empty]', 'Logonya lebih terlihat seperti logo kaum pagan para penyembah matahari!'], ['Jun 2', '[empty]', 'Udah. Biarkan aja. IKN gak bakal lanjut kok. Mau pake logo apapun gak ngefek.. kecuali ada yg main kayu'], ['Jun 2', '[empty]', 'Yg biki ...
# diakhir [['Jun 2', '[empty]', 'Ya semoga mangkrak, aamiin.'], ['Jun 2', '[empty]', 'Walah .. hanya gimmick yg memuakkan.\nMembuat logo pohon hayati tetapi realnya membuat pohon tidak hayat .. \nKan lonthong .\nAsssuuuuudahlah'], ['Jun 2', '[empty]', 'Hayat asal kata dari arab.. Nanti dikatakan kadrun?!'], ['Jun 2', '[empty]', '[empty]'], ['Jun 2', '[empty]', 'Logo itu pakai Garuda Pancasila...selesai..'], ['Jun 2', '[empty]', 'Logonya pohon tidak berdaun karena daunnya sudah dibabat oleh yang punya proyek '], ['Jun 2', '[empty]', 'Lah terus kalau ada di Alkitab emg ngapa? Bego nih yg buat artikel.'], ['Jun 2', '[empty]', 'Yang mendesign namanya Aulia Akbar….dari namanya 99% terlihat agamanya apa, kecuali orang tuanya pengen terlalu unik.'], ['Jun 2', '[empty]', 'Mirip dajjal'], ['Jun 2', '[empty]', 'Waduh ...... Aku gak ikut milih euy... sayank sekali'], ['Jun 2', '[empty]', 'Ya semoga mangkrak, aamiin.'], ['Jun 2', '[empty]', 'Walah .. hanya gimmick yg memuakkan.\nMembuat logo pohon hayati tetapi realnya membuat pohon tidak hayat .. \nKan lonthong .\nAsssuuuuudahlah'], ['Jun 2', '[empty]', 'Hayat asal kata dari arab.. Nanti dikatakan kadrun?!'], ['Jun 2', '[empty]', '[empty]'], ['Jun 2', '[empty]', 'Logo itu pakai Garuda Pancasila...selesai..'], ['Jun 2', '[empty]', 'Logonya pohon tidak berdaun karena daunnya sudah dibabat oleh yang punya proyek '], ['Jun 2', '[empty]', 'Lah terus kalau ada di Alkitab emg ngapa? Bego nih yg buat artikel.'], ['Jun 2', '[empty]', 'Yang mendesign namanya Aulia Akbar….dari namanya 99% terlihat agamanya apa, kecuali orang tuanya pengen terlalu unik.'], ['Jun 2', '[empty]', 'Mirip dajjal'], ['Jun 2', '[empty]', 'Waduh ...... Aku gak ikut milih euy... sayank sekali'], ['Jun 2', '[empty]', 'Bukan hanya pohon yg ada disitu. Adam dan hawa pun ada di situ. Tolol kok dipelihara'], ['Jun 2', '[empty]', 'Sudahlah segala logo dimasalahin'], ['Jun 2', '[empty]', 'Hahaha modyar'], ['Jun 2', '[empty]', 'Biaya IkN ratusan triliun hasilnya cuma logo doang..'], ['Jun 2', '[empty]', 'IKN hanya imajinasi mukidi, ngibul dan bahlul.'], ['Jun 2', '[empty]', '.. pindah ibukota serasa pindah kontrakan '], ['Jun 2', '[empty]', '.. pindah ibukota serasa pindah kontrakan '], ['Jun 2', '[empty]', '@Uing0095\n katanya yg Pilih itu Rakyat. rakyat mana ya??? lihat aja baru, boro² milih... Maneh Ngacapruk'], ['Jun 2', '[empty]', 'IKN = IBU KOTA NGUTANG'], ['Jun 2', '[empty]', 'IKN Residence, senin harga naik, sabtu diskon lagi..'], ['Jun 2', '[empty]', 'Kenapa gak pake lambang burung garuda aja biar kelihatan pancasila nya'], ['Jun 2', '[empty]', 'Admin nya emank sengaja jadi provokator terus kenapa kalau di Alkitab??? Hedewww'], ['Jun 2', '[empty]', 'IKN= IBU KOTA NGEDABRUS iya ga pak de \n@jokowi'], ['Jun 2', '[empty]', 'bisa saja desain pohon hayat menggambarkan bahwa rencana IKN hingga akhir hayat gak bakal bisa terwujud. '], ['Jun 2', '[empty]', 'Logo pohon, tapi pohon d kalimantan dibabat'], ['Jun 2', '[empty]', 'Pohon Kehidupan Suku Dayak Ngaju, Kalteng'], ['Jun 2', '[empty]', 'IKN bakalan jadi akan mangkrak..'], ['Jun 2', '[empty]', 'Kenapa gak pake lambang burung garuda aja biar kelihatan pancasila nya'], ['Jun 2', '[empty]', 'Admin nya emank sengaja jadi provokator terus kenapa kalau di Alkitab??? Hedewww'], ['Jun 2', '[empty]', 'IKN= IBU KOTA NGEDABRUS iya ga pak de \n@jokowi'], ['Jun 2', '[empty]', 'bisa saja desain pohon hayat menggambarkan bahwa rencana IKN hingga akhir hayat gak bakal bisa terwujud. '], ['Jun 2', '[empty]', 'Logo pohon, tapi pohon d kalimantan dibabat'], ['Jun 2', '[empty]', 'Pohon Kehidupan Suku Dayak Ngaju, Kalteng'], ['Jun 2', '[empty]', 'IKN bakalan jadi akan mangkrak..'], ['Jun 2', '[empty]', 'Logonya pohon, tp pohonnya ditebang.'], ['Jun 2', '[empty]', 'Logonya lebih terlihat seperti logo kaum pagan para penyembah matahari!'], ['Jun 2', '[empty]', 'Udah. Biarkan aja. IKN gak bakal lanjut kok. Mau pake logo apapun gak ngefek.. kecuali ada yg main kayu'], ['Jun 2', '[empty]', 'Yg bikin orng m ...
